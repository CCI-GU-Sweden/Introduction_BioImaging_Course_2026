# %% [markdown]
# # Python Basics — Live Coding Session
#
# **Session length:** 1 hour 15 minutes
# **Audience:** Complete beginners
#
# ## Learning goals
#
# By the end of this session, you should be able to:
#
# - create and use variables
# - recognize common Python data types
# - work with strings, integers, floats, and booleans
# - create readable text using f-strings
# - make decisions using `if` statements
# - store multiple values in lists
# - repeat actions using `for` loops
# - iterate through lists
# - build a new list using `.append()`
#
# > **Instructor note:** This notebook is designed for live coding. Type the examples together with the students instead of rushing through the cells.

# %% [markdown]
# ## Suggested timing
#
# | Topic | Time |
# |---|---:|
# | Welcome + running Python | 5 min |
# | Variables and types | 15 min |
# | f-strings | 8 min |
# | `if` statements | 12 min |
# | Lists | 8 min |
# | `for` loops | 12 min |
# | Iterating + `.append()` | 10 min |
# | Final exercise + recap | 5 min |
#
# The timings are approximate. Spend more time where students have questions.

# %% [markdown]
# # 1. Your first Python code
#
# Python can perform calculations and display results.
#
# The `print()` function shows something on the screen.

# %%
# print hello world

# %%
# print the sum of 2 and 3

# %% [markdown]
# Try changing the text and the numbers above.
#
# A useful habit when learning programming is:
#
# 1. make a small change
# 2. run the code
# 3. observe what happened

# %% [markdown]
# # 2. Variables
#
# A **variable** is a name that refers to a value.
#
# We create a variable using `=`.

# %%
# create a variable and print it

# %% [markdown]
# Read this as:
#
# - put the value `"Alex"` into a variable called `name`
# - put the value `24` into a variable called `age`
#
# The variable name is on the **left** side of `=`.
# The value is on the **right** side.

# %%
# create two variables and print them in one line

# %% [markdown]
# Variables can be changed:

# %%
# create a numeric variable, print it, then change it and print it again

# %% [markdown]
# ## Variable naming
#
# Good variable names describe what the value represents.
#
# ```python
# student_name = "Sven"
# number_of_cells = 25
# average_area = 42.7
# ```
#
# Avoid unclear names such as:
#
# ```python
# x = 25
# a = 42.7
# ```
#
# unless the meaning is obvious from the context.

# %% [markdown]
# ## Exercise 1 - Create some variables
#
# Create variables for:
#
# - your name
# - your age
# - your favorite number
#
# Then print all three variables.

# %%
# Write your code here

# %% [markdown]
# # 3. Variable types
#
# Values in Python have different **types**.
#
# Today we will use four common types:
#
# | Type | Meaning | Example |
# |---|---|---|
# | `str` | text | `"hello"` |
# | `int` | whole number | `42` |
# | `float` | decimal number | `3.14` |
# | `bool` | true/false value | `True` |
#
# Python can tell us the type of a value using `type()`.

# %%
student_name = "Maya"
number_of_images = 12
average_area = 34.7
is_complete = True

print(type(student_name))
print(type(number_of_images))
print(type(average_area))
print(type(is_complete))

# %% [markdown]
# ## Strings
#
# Strings contain text and are written inside quotes.

# %%
# create a string variable and print it

# %% [markdown]
# You can combine two strings with ```+```

# %%
# combine two string variables and print them

# %% [markdown]
# ## Integers
#
# Integers are whole numbers.

# %%
# create two integer variables and subtract them

# %% [markdown]
# You can do typical mathematical operations with integers

# %%
# create two variables, print the sum, difference, product, quotient and one raised to the power of the other

# %% [markdown]
# ## Floats
#
# Floats are numbers containing a decimal point. You can do the same mathematical operations as with integers.

# %%
# create a couple of floats and add them.

# %% [markdown]
# ## Booleans
#
# A Boolean can only have two values:
#
# ```python
# True
# False
# ```
#
# Notice that they start with capital letters and do **not** use quotation marks.

# %%
# create and print a true and a false boolean variable

# %% [markdown]
# Booleans often come from comparisons:

# %%
# create an int variable and demonstrate some operators

# %% [markdown]
# Some comparison operators:
#
# | Operator | Meaning |
# |---|---|
# | `==` | equal to |
# | `!=` | not equal to |
# | `>` | greater than |
# | `<` | less than |
# | `>=` | greater than or equal to |
# | `<=` | less than or equal to |
#
# Be careful:
#
# - `=` assigns a value
# - `==` compares two values

# %% [markdown]
# ## Exercise 2 - What type is it?
#
# Before running the cell, predict the type of each variable.

# %%
sample_name = "Control"
image_number = 8
mean_intensity = 127.4
passed_quality_check = False

print(type(sample_name))
print(type(image_number))
print(type(mean_intensity))
print(type(passed_quality_check))

# %% [markdown]
# # 4. f-strings
#
# We often want to combine variables with text.
#
# An **f-string** lets us insert variables directly into a string.

# %% [markdown]
# The important pieces are:
#
# ```python
# f"text {variable}"
# ```
#
# - put `f` before the opening quotation mark
# - put variables inside `{ }`

# %%
# Use an f-string to print a message that includes the value of some variable

# %% [markdown]
# You can also put calculations inside the curly brackets:

# %%
# create two number variables and print a message that includes their product using an f-string

# %% [markdown]
# ## Exercise 3 - Make a sentence
#
# Create three variables:
#
# - `student`
# - `course`
# - `week`
#
# Then use one f-string to print a sentence such as:
#
# > Alex is taking Python Basics in week 3.

# %%
# Write your code here

# %% [markdown]
# # 5. Making decisions with `if`
#
# Programs often need to make decisions.
#
# An `if` statement runs code **only when a condition is true**.

# %%
# create a variable, and print a message if it fulfils some condition

# %% [markdown]
# Two important syntax rules:
#
# ```python
# if condition:
#     indented_code
# ```
#
# 1. the `if` line ends with `:`
# 2. the code inside the `if` statement is indented

# %% [markdown]
# What happens if the condition is false, and after the if statement is complete?

# %%
temperature = 15

if temperature > 20:
    print("It is warm.")

print("Finished checking the temperature.")

# %% [markdown]
# ## `if` and `else`
#
# Use `else` when you want one thing to happen if the condition is true and something else if it is false.

# %%
# demonstrate if/else statements

# %% [markdown]
# ## `if`, `elif`, and `else`
#
# Use `elif` when there are several possible cases. The lines of code are executed in order, and if the condition is fulfiled, then we exit the if statement.

# %%
# demonstrate if, elif and else. Print something after termination.

# %% [markdown]
# Python checks the conditions from top to bottom and stops at the first condition that is true.

# %% [markdown]
# The term after the if statement is a boolean! ```If``` is checking whether this boolean is True or False

# %%
# create a boolean variable from some condition, and use that in an if statement

# %% [markdown]
# ## Exercise 4 - Positive or negative?
#
# Create a variable called `number`.
#
# Write an `if` statement that prints:
#
# - `"Positive"` if the number is greater than 0
# - `"Zero or negative"` otherwise
#
# Try your code with several different numbers.

# %%
# Write your code here

# %% [markdown]
# # 6. Lists
#
# A **list** stores multiple values in one variable.
#
# Lists use square brackets `[ ]`.

# %%
# create a list of floats and print it

# %% [markdown]
# Lists can contain strings:

# %%
# create a list of strings and print it

# %% [markdown]
# We can access individual items using their position.
#
# Python starts counting at **0**.

# %%
# print each element of the list above

# %% [markdown]
# So:
#
# | Position | Index | Value |
# |---:|---:|---|
# | first | `0` | `"Control"` |
# | second | `1` | `"Treatment A"` |
# | third | `2` | `"Treatment B"` |
#
# This zero-based indexing is very common in Python.

# %% [markdown]
# We can check how many items are in a list with `len()`.

# %%
# demonstrate len() of some list

# %% [markdown]
# # 7. `for` loops
#
# A `for` loop repeats code.
#
# This is especially useful when we have a list. When we use a for loop to access the terms in a list one by one, this is called **looping** or more formally, **iteration**.

# %%
# iterate through a list (call the iterator sample) and print each element

# %% [markdown]
# Read this as:
#
# > For each `sample` in the list `samples`, print the sample.
#
# The variable `sample` temporarily represents one item from the list at a time.

# %%
# iterate through a list, create a variable that adds 5 to the term and print that variable

# %% [markdown]
# We can combine loops with f-strings:

# %%
# demonstrate iterating through a list of strings and printing a message that includes the string
# Out:
# Welcome, Anna!
# Welcome, Leo!
# Welcome, Nora!

# %% [markdown]
# And we can combine loops with `if` statements:

# %%
# demonstrate the use of a for loop to iterate over a list of numbers and print whether they are greater than 20

# %% [markdown]
# We might also want access to the index when iterating through a list. This is done using ```enumerate()```

# %%
# demonstrate enumeration

# %% [markdown]
# ## Exercise 5 - Loop through a list
#
# Create a list containing four animal names.
#
# Use a `for` loop to print:
#
# ```text
# I like cats
# I like dogs
# ...
# ```
#
# using an f-string.

# %%
# Write your code here

# %% [markdown]
# # 8. Building lists with `.append()`
#
# Sometimes we want to create a new list while looping over another list.
#
# Start with an empty list:

# %%
# create and print an empty list

# %% [markdown]
# Then add items using `.append()`.

# %%
# append some values and print the updated list

# %% [markdown]
# This becomes especially useful inside a loop.

# %%
# use a for loop to double each element of a list, append the result to a new list and print this

# %% [markdown]
# Let's follow what happens:
#
# 1. `doubled_numbers` starts empty
# 2. Python takes the first number
# 3. it calculates `number * 2`
# 4. `.append()` adds the result to the new list
# 5. the loop repeats for every number

# %% [markdown]
# Another example: keep only values that pass a condition.

# %%
# append values to a list that pass some condition

# %% [markdown]
# ## Exercise 6 - Create a new list
#
# Given this list:

# %%
numbers = [2, 5, 8, 11, 14]

# %% [markdown]
# Create an empty list called `large_numbers`.
#
# Loop through `numbers`.
#
# If a number is greater than `7`, append it to `large_numbers`.
#
# At the end, print the new list.
#
# Expected result:
#
# ```python
# [8, 11, 14]
# ```

# %%
# Write your code here

# %% [markdown]
# # 9. Final mini-challenge
#
# Let's combine everything.
#
# You have measurements from several objects:

# %%
areas = [12.5, 28.4, 7.9, 35.2, 18.6]

# %% [markdown]
# Your task:
#
# 1. create an empty list called `large_areas`
# 2. loop through `areas`
# 3. if an area is greater than `20`, append it to `large_areas`
# 4. print an f-string for every large area and its index: `"At index 2, found a large area: 28.4"`
# 5. after the loop, print the final list
#
# Try to solve it without looking at the solution.

# %%
# Write your code here

# %% [markdown]
# # 10. Recap
#
# Today you used:
#
# ```python
# # Variables
# name = "Alex"
# age = 20
#
# # Common types
# text = "hello"       # str
# count = 5            # int
# measurement = 2.5    # float
# is_valid = True      # bool
#
# # f-string
# print(f"Hello {name}")
#
# # if statement
# if age >= 18:
#     print("Adult")
#
# # list
# numbers = [1, 2, 3]
#
# # for loop
# for number in numbers:
#     print(number)
#
# # append
# results = []
#
# for number in numbers:
#     results.append(number * 2)
# ```
#
# ## The main ideas
#
# - Variables give names to values.
# - Different values have different types.
# - f-strings combine variables and text.
# - `if` statements let programs make decisions.
# - Lists store multiple values.
# - `for` loops repeat an action.
# - `.append()` adds values to a list.
#
# Programming becomes easier through practice. Small experiments are encouraged!

# %% [markdown]
# # Optional extra exercises
#
# Use these only if the group moves quickly or as take-home practice.
#
# ## Extra 1
#
# Create a list of five numbers. Print only the numbers that are greater than 10.
#
# ## Extra 2
#
# Create a list of names. Build a new list containing the sentence `"Hello NAME"` for each person.
#
# For example:
#
# ```python
# ["Hello Anna", "Hello Max", "Hello Sara"]
# ```
#
# ## Extra 3
#
# Create a list of temperatures. Build two new lists:
#
# - `warm`
# - `cold`
#
# Put temperatures greater than 20 into `warm` and everything else into `cold`.
#
# Then print both lists.
